# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import textwrap

# %%
sc.settings.verbosity = 3 
sc.logging.print_header()
sc.settings.set_figure_params(dpi=300, transparent = True, format = 'pdf', vector_friendly = True)

# %%
figure = "Figure_sup_cluster"

# %%
sc.settings.figdir = './Figure_plots/'+figure

# %%
umap_cmap = sns.blend_palette(['xkcd:light grey', 'xkcd:blueberry'], as_cmap = True)

# %% [markdown]
# # Declaring the input files

# %%
adata = sc.read_h5ad('./h5ad/analysis_250528_f/Smed_L78-L47_20250523_Annotated.h5ad')

# %%
adata

# %%
samp = 'Sample'

# %%
clusteringlayer = 'annotated_names'

# %% [markdown]
# # Plots

# %% [markdown]
# ## annotation and samples

# %%
with plt.rc_context({'figure.figsize': (10, 10)}):
    sc.pl.umap(adata, color=clusteringlayer, legend_loc = None, size = 30,
        frameon=False)

# %%
adata.obs['broad_names'].cat.categories

# %%
adata.obs['annotated_names'].cat.categories

# %%
# use this object to test the figure
adata_test = adata[np.random.choice(adata.obs_names, 2000, replace=False)].copy()

# %%
# test of the code

# define the layout
layout = [
    # neoblasts
    {"name": "neoblasts", "size": "BIG", "start_row": 0, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "neoblasts 1", "size": "SMALL", "start_row": 0, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 2",  "size": "SMALL", "start_row": 0, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 3",  "size": "SMALL", "start_row": 0, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 4",  "size": "SMALL", "start_row": 0, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 5", "size": "SMALL", "start_row": 0, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 6",  "size": "SMALL", "start_row": 1, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 7",  "size": "SMALL", "start_row": 1, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 8",  "size": "SMALL", "start_row": 1, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 9",  "size": "SMALL", "start_row": 1, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "germ cells progenitors", "size": "SMALL", "start_row": 1, "start_col": 6, "rowspan": 1, "colspan": 1},
    
    # neurons
    {"name": "neurons", "size": "BIG", "start_row": 2, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "neuronal progenitors", "size": "SMALL", "start_row": 2, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "celsr-1+ neurons",  "size": "SMALL", "start_row": 2, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "chat+ neurons 1",  "size": "SMALL", "start_row": 2, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "chat+ neurons 2",  "size": "SMALL", "start_row": 2, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "chat+ neurons 3", "size": "SMALL", "start_row": 2, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "chat+ neurons 4",  "size": "SMALL", "start_row": 3, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "gabrb-3+ neurons",  "size": "SMALL", "start_row": 3, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "grik1+ neurons",  "size": "SMALL", "start_row": 3, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "th+ neurons",  "size": "SMALL", "start_row": 3, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "otf+ neurons 1",  "size": "SMALL", "start_row": 3, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "otf+ neurons 2",  "size": "SMALL", "start_row": 4, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "para+ neurons 1", "size": "SMALL", "start_row": 4, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "para+ neurons 2",  "size": "SMALL", "start_row": 4, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "pkd-1+ neurons",  "size": "SMALL", "start_row": 4, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "pkd-2+ neurons",  "size": "SMALL", "start_row": 4, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "pth1r+ neurons", "size": "SMALL", "start_row": 4, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "tinc+ neurons",  "size": "SMALL", "start_row": 4, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "tph+ neurons",  "size": "SMALL", "start_row": 5, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "trpa1+ neurons",  "size": "SMALL", "start_row": 5, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "trpm-2-1+ neurons",  "size": "SMALL", "start_row": 5, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "unanotated neurons 1 ",  "size": "SMALL", "start_row": 5, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "unanotated neurons 2",  "size": "SMALL", "start_row": 5, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 3",  "size": "SMALL", "start_row": 5, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 4", "size": "SMALL", "start_row": 5, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 5",  "size": "SMALL", "start_row": 6, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 6",  "size": "SMALL", "start_row": 6, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 7",  "size": "SMALL", "start_row": 6, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 8",  "size": "SMALL", "start_row": 6, "start_col": 3, "rowspan": 1, "colspan": 1},

    # muscle
    {"name": "muscle", "size": "BIG", "start_row": 6, "start_col": 5, "rowspan": 2, "colspan": 2},
    {"name": "muscle progenitors", "size": "SMALL", "start_row": 6, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "intestinal and DV muscle",  "size": "SMALL", "start_row": 7, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "body wall muscle",  "size": "SMALL", "start_row": 7, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "muscle pharynx",  "size": "SMALL", "start_row": 7, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "unannotated muscle 1", "size": "SMALL", "start_row": 7, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "unannotated muscle 2",  "size": "SMALL", "start_row": 7, "start_col": 4, "rowspan": 1, "colspan": 1},
    
    # parenchymal
    {"name": "parenchymal", "size": "BIG", "start_row": 8, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "parenchymal progenitors", "size": "SMALL", "start_row": 8, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "aqp+ parenchymal cells",  "size": "SMALL", "start_row": 8, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "ldlrr+ parenchymal cells",  "size": "SMALL", "start_row": 8, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "pgrn+ parenchymal cells 1",  "size": "SMALL", "start_row": 8, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "pgrn+ parenchymal cells 2", "size": "SMALL", "start_row": 8, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "psap+ parenchymal cells",  "size": "SMALL", "start_row": 9, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "ubc+ parenchymal cells",  "size": "SMALL", "start_row": 9, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "unannotated parenchymal cells", "size": "SMALL", "start_row": 9, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "pigment cells",  "size": "SMALL", "start_row": 9, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "glia",  "size": "SMALL", "start_row": 9, "start_col": 6, "rowspan": 1, "colspan": 1},
    
    # epidermis
    {"name": "epidermis", "size": "BIG", "start_row": 10, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "early epidermal progenitors", "size": "SMALL", "start_row": 10, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "late epidermal progenitors",  "size": "SMALL", "start_row": 10, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 1",  "size": "SMALL", "start_row": 10, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 2",  "size": "SMALL", "start_row": 10, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 3", "size": "SMALL", "start_row": 10, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 4",  "size": "SMALL", "start_row": 11, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 5",  "size": "SMALL", "start_row": 11, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "epidermis DVB and progenitors", "size": "SMALL", "start_row": 11, "start_col": 4, "rowspan": 1, "colspan": 1},
    
    #gut
    {"name": "phagocytes", "size": "BIG", "start_row": 11, "start_col": 5, "rowspan": 2, "colspan": 2},
    {"name": "gut progenitors",  "size": "SMALL", "start_row": 12, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "phagocyte progenitors",  "size": "SMALL", "start_row": 12, "start_col": 3, "rowspan": 1, "colspan": 1},    
    {"name": "phagocytes",  "size": "SMALL", "start_row": 12, "start_col": 4, "rowspan": 1, "colspan": 1},   
    
    # secretory
    {"name": "secretory", "size": "BIG", "start_row": 12, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "secretory 1", "size": "SMALL", "start_row": 13, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "secretory 2 and progenitors",  "size": "SMALL", "start_row": 13, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "secretory 3a and progenitors",  "size": "SMALL", "start_row": 13, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "secretory 3b and progenitors",  "size": "SMALL", "start_row": 13, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "secretory 4 and progenitors", "size": "SMALL", "start_row": 13, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "secretory 5",  "size": "SMALL", "start_row": 14, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "secretory 6",  "size": "SMALL", "start_row": 14, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "secretory 7 and progenitors", "size": "SMALL", "start_row": 14, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "secretory 8 and progenitors",  "size": "SMALL", "start_row": 14, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "secretory 9 and progenitors", "size": "SMALL", "start_row": 14, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "secretory 10",  "size": "SMALL", "start_row": 14, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "secretory 11 and progenitors",  "size": "SMALL", "start_row": 14, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "secretory 12 and progenitors", "size": "SMALL", "start_row": 15, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "secretory 13 and progenitors", "size": "SMALL", "start_row": 15, "start_col": 1, "rowspan": 1, "colspan": 1},    

    # protonephridia
    {"name": "protonephridia", "size": "BIG", "start_row": 15, "start_col": 5, "rowspan": 2, "colspan": 2},
    {"name": "protonephridia proximal tubule cells", "size": "SMALL", "start_row": 15, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "protonephridia distal tubule cells",  "size": "SMALL", "start_row": 15, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "protonephridia flame cells",  "size": "SMALL", "start_row": 15, "start_col": 4, "rowspan": 1, "colspan": 1},
    
   # basal goblet
    {"name": "basal goblet", "size": "BIG", "start_row": 16, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "goblet cells and progenitors", "size": "SMALL", "start_row": 16, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "basal cells",  "size": "SMALL", "start_row": 17, "start_col": 2, "rowspan": 1, "colspan": 1},   
    
   # pharynx
    {"name": "pharynx", "size": "BIG", "start_row": 16, "start_col": 3, "rowspan": 2, "colspan": 2},   
    
    #psd+ cells
    {"name": "psd+ cells", "size": "BIG", "start_row": 17, "start_col": 5, "rowspan": 2, "colspan": 2},    
    
    # unannotated
    {"name": "unannotated 1", "size": "SMALL", "start_row": 18, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "unannotated 2",  "size": "SMALL", "start_row": 18, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "unannotated 3",  "size": "SMALL", "start_row": 18, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "unannotated 4",  "size": "SMALL", "start_row": 18, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "unannotated 5", "size": "SMALL", "start_row": 18, "start_col": 4, "rowspan": 1, "colspan": 1},       
]

# Create the figure and grid
sc.settings.set_figure_params(dpi=50, frameon=False, transparent=True) # for tests only
plt.ioff()  # for tests only
fig = plt.figure(figsize=(20, 60)) # to make the umaps square, the size needs to be proportional to the size of the grid + the space
gs = gridspec.GridSpec(19, 7, figure=fig, wspace=0.01, hspace=0.2)


# Loop over layout and plot each UMAP
for plot in layout:
    r0, c0 = plot["start_row"], plot["start_col"]
    rspan, cspan = plot["rowspan"], plot["colspan"]
    ax = fig.add_subplot(gs[r0:r0+rspan, c0:c0+cspan])
    
    if plot["size"] == "BIG": # big umap for broad names
        sc.pl.umap(
            adata,
            color="broad_names",
            groups=[plot["name"]],
            size=15,
            alpha=0.6, # for tests only
            ax=ax,
            show=False, 
            #title=plot["name"], 
            frameon=False,      
            legend_loc=None, 
            na_color="#f0f0f0"
            )

    if plot["size"] == "SMALL": # small umap with annotated_names
        sc.pl.umap(
            adata,
            color="annotated_names",
            groups=[plot["name"]],
            size = 5,
            alpha=0.6, # for tests only
            ax=ax,
            show=False, 
            #title=plot["name"],
            frameon=False,      
            legend_loc=None,  
            na_color='#f0f0f0'
        )
    
    # title on 2 lines to prevent overlap
    max_width = 22 
    title_wrapped = "\n".join(textwrap.wrap(plot["name"], max_width))

    ax.set_title(title_wrapped)

#plt.savefig('./Figure_plots/'+ figure + '/' + figure + "_umap_clusters.pdf", bbox_inches='tight')
plt.show()

# %%
sc.settings.set_figure_params(dpi=300, transparent = True, format = 'pdf', vector_friendly = True)

# %%
# figure in full resolution

# define the layout
layout = [
    # neoblasts
    {"name": "neoblasts", "size": "BIG", "start_row": 0, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "neoblasts 1", "size": "SMALL", "start_row": 0, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 2",  "size": "SMALL", "start_row": 0, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 3",  "size": "SMALL", "start_row": 0, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 4",  "size": "SMALL", "start_row": 0, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 5", "size": "SMALL", "start_row": 0, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 6",  "size": "SMALL", "start_row": 1, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 7",  "size": "SMALL", "start_row": 1, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 8",  "size": "SMALL", "start_row": 1, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "neoblasts 9",  "size": "SMALL", "start_row": 1, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "germ cells progenitors", "size": "SMALL", "start_row": 1, "start_col": 6, "rowspan": 1, "colspan": 1},
    
    # neurons
    {"name": "neurons", "size": "BIG", "start_row": 2, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "neuronal progenitors", "size": "SMALL", "start_row": 2, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "celsr-1+ neurons",  "size": "SMALL", "start_row": 2, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "chat+ neurons 1",  "size": "SMALL", "start_row": 2, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "chat+ neurons 2",  "size": "SMALL", "start_row": 2, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "chat+ neurons 3", "size": "SMALL", "start_row": 2, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "chat+ neurons 4",  "size": "SMALL", "start_row": 3, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "gabrb-3+ neurons",  "size": "SMALL", "start_row": 3, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "grik1+ neurons",  "size": "SMALL", "start_row": 3, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "th+ neurons",  "size": "SMALL", "start_row": 3, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "otf+ neurons 1",  "size": "SMALL", "start_row": 3, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "otf+ neurons 2",  "size": "SMALL", "start_row": 4, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "para+ neurons 1", "size": "SMALL", "start_row": 4, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "para+ neurons 2",  "size": "SMALL", "start_row": 4, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "pkd-1+ neurons",  "size": "SMALL", "start_row": 4, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "pkd-2+ neurons",  "size": "SMALL", "start_row": 4, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "pth1r+ neurons", "size": "SMALL", "start_row": 4, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "tinc+ neurons",  "size": "SMALL", "start_row": 4, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "tph+ neurons",  "size": "SMALL", "start_row": 5, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "trpa1+ neurons",  "size": "SMALL", "start_row": 5, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "trpm-2-1+ neurons",  "size": "SMALL", "start_row": 5, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "unanotated neurons 1 ",  "size": "SMALL", "start_row": 5, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "unanotated neurons 2",  "size": "SMALL", "start_row": 5, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 3",  "size": "SMALL", "start_row": 5, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 4", "size": "SMALL", "start_row": 5, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 5",  "size": "SMALL", "start_row": 6, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 6",  "size": "SMALL", "start_row": 6, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 7",  "size": "SMALL", "start_row": 6, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "unannotated neurons 8",  "size": "SMALL", "start_row": 6, "start_col": 3, "rowspan": 1, "colspan": 1},

    # muscle
    {"name": "muscle", "size": "BIG", "start_row": 6, "start_col": 5, "rowspan": 2, "colspan": 2},
    {"name": "muscle progenitors", "size": "SMALL", "start_row": 6, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "intestinal and DV muscle",  "size": "SMALL", "start_row": 7, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "body wall muscle",  "size": "SMALL", "start_row": 7, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "muscle pharynx",  "size": "SMALL", "start_row": 7, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "unannotated muscle 1", "size": "SMALL", "start_row": 7, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "unannotated muscle 2",  "size": "SMALL", "start_row": 7, "start_col": 4, "rowspan": 1, "colspan": 1},
    
    # parenchymal
    {"name": "parenchymal", "size": "BIG", "start_row": 8, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "parenchymal progenitors", "size": "SMALL", "start_row": 8, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "aqp+ parenchymal cells",  "size": "SMALL", "start_row": 8, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "ldlrr+ parenchymal cells",  "size": "SMALL", "start_row": 8, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "pgrn+ parenchymal cells 1",  "size": "SMALL", "start_row": 8, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "pgrn+ parenchymal cells 2", "size": "SMALL", "start_row": 8, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "psap+ parenchymal cells",  "size": "SMALL", "start_row": 9, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "ubc+ parenchymal cells",  "size": "SMALL", "start_row": 9, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "unannotated parenchymal cells", "size": "SMALL", "start_row": 9, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "pigment cells",  "size": "SMALL", "start_row": 9, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "glia",  "size": "SMALL", "start_row": 9, "start_col": 6, "rowspan": 1, "colspan": 1},
    
    # epidermis
    {"name": "epidermis", "size": "BIG", "start_row": 10, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "early epidermal progenitors", "size": "SMALL", "start_row": 10, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "late epidermal progenitors",  "size": "SMALL", "start_row": 10, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 1",  "size": "SMALL", "start_row": 10, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 2",  "size": "SMALL", "start_row": 10, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 3", "size": "SMALL", "start_row": 10, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 4",  "size": "SMALL", "start_row": 11, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "epidermis 5",  "size": "SMALL", "start_row": 11, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "epidermis DVB and progenitors", "size": "SMALL", "start_row": 11, "start_col": 4, "rowspan": 1, "colspan": 1},
    
    #gut
    {"name": "phagocytes", "size": "BIG", "start_row": 11, "start_col": 5, "rowspan": 2, "colspan": 2},
    {"name": "gut progenitors",  "size": "SMALL", "start_row": 12, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "phagocyte progenitors",  "size": "SMALL", "start_row": 12, "start_col": 3, "rowspan": 1, "colspan": 1},    
    {"name": "phagocytes",  "size": "SMALL", "start_row": 12, "start_col": 4, "rowspan": 1, "colspan": 1},   
    
    # secretory
    {"name": "secretory", "size": "BIG", "start_row": 12, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "secretory 1", "size": "SMALL", "start_row": 13, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "secretory 2 and progenitors",  "size": "SMALL", "start_row": 13, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "secretory 3a and progenitors",  "size": "SMALL", "start_row": 13, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "secretory 3b and progenitors",  "size": "SMALL", "start_row": 13, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "secretory 4 and progenitors", "size": "SMALL", "start_row": 13, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "secretory 5",  "size": "SMALL", "start_row": 14, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "secretory 6",  "size": "SMALL", "start_row": 14, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "secretory 7 and progenitors", "size": "SMALL", "start_row": 14, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "secretory 8 and progenitors",  "size": "SMALL", "start_row": 14, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "secretory 9 and progenitors", "size": "SMALL", "start_row": 14, "start_col": 4, "rowspan": 1, "colspan": 1},
    {"name": "secretory 10",  "size": "SMALL", "start_row": 14, "start_col": 5, "rowspan": 1, "colspan": 1},
    {"name": "secretory 11 and progenitors",  "size": "SMALL", "start_row": 14, "start_col": 6, "rowspan": 1, "colspan": 1},
    {"name": "secretory 12 and progenitors", "size": "SMALL", "start_row": 15, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "secretory 13 and progenitors", "size": "SMALL", "start_row": 15, "start_col": 1, "rowspan": 1, "colspan": 1},    

    # protonephridia
    {"name": "protonephridia", "size": "BIG", "start_row": 15, "start_col": 5, "rowspan": 2, "colspan": 2},
    {"name": "protonephridia proximal tubule cells", "size": "SMALL", "start_row": 15, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "protonephridia distal tubule cells",  "size": "SMALL", "start_row": 15, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "protonephridia flame cells",  "size": "SMALL", "start_row": 15, "start_col": 4, "rowspan": 1, "colspan": 1},
    
   # basal goblet
    {"name": "basal goblet", "size": "BIG", "start_row": 16, "start_col": 0, "rowspan": 2, "colspan": 2},
    {"name": "goblet cells and progenitors", "size": "SMALL", "start_row": 16, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "basal cells",  "size": "SMALL", "start_row": 17, "start_col": 2, "rowspan": 1, "colspan": 1},   
    
   # pharynx
    {"name": "pharynx", "size": "BIG", "start_row": 16, "start_col": 3, "rowspan": 2, "colspan": 2},   
    
    #psd+ cells
    {"name": "psd+ cells", "size": "BIG", "start_row": 17, "start_col": 5, "rowspan": 2, "colspan": 2},    
    
    # unannotated
    {"name": "unannotated 1", "size": "SMALL", "start_row": 18, "start_col": 0, "rowspan": 1, "colspan": 1},
    {"name": "unannotated 2",  "size": "SMALL", "start_row": 18, "start_col": 1, "rowspan": 1, "colspan": 1},
    {"name": "unannotated 3",  "size": "SMALL", "start_row": 18, "start_col": 2, "rowspan": 1, "colspan": 1},
    {"name": "unannotated 4",  "size": "SMALL", "start_row": 18, "start_col": 3, "rowspan": 1, "colspan": 1},
    {"name": "unannotated 5", "size": "SMALL", "start_row": 18, "start_col": 4, "rowspan": 1, "colspan": 1},       
]

# Create the figure and grid
fig = plt.figure(figsize=(20, 60)) # to make the umaps square, the size needs to be proportional to the size of the grid + the space
gs = gridspec.GridSpec(19, 7, figure=fig, wspace=0.01, hspace=0.2)


# Loop over layout and plot each UMAP
for plot in layout:
    r0, c0 = plot["start_row"], plot["start_col"]
    rspan, cspan = plot["rowspan"], plot["colspan"]
    ax = fig.add_subplot(gs[r0:r0+rspan, c0:c0+cspan])
    
    if plot["size"] == "BIG": # big umap for broad names
        sc.pl.umap(
            adata,
            color="broad_names",
            groups=[plot["name"]],
            size=15,
            ax=ax,
            show=False, 
            frameon=False,      
            legend_loc=None, 
            na_color="#f0f0f0"
            )

    if plot["size"] == "SMALL": # small umap with annotated_names
        sc.pl.umap(
            adata,
            color="annotated_names",
            groups=[plot["name"]],
            size = 5,
            ax=ax,
            show=False, 
            frameon=False,      
            legend_loc=None,  
            na_color='#f0f0f0'
        )
    
    # title on 2 lines to prevent overlap
    max_width = 22 
    title_wrapped = "\n".join(textwrap.wrap(plot["name"], max_width))

    ax.set_title(title_wrapped)

plt.savefig('./Figure_plots/'+ figure + '/' + figure + "_umap_clusters.pdf", bbox_inches='tight')
plt.show()
